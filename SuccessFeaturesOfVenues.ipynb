# %%
import pandas as pd
import numpy as np

city      = 'london'
outfolder = '../ProcessedData/' + city + '/'

# %%
lsoa     = outfolder + 'venues_info/venues_lsoa_full.dat'
msoa     = outfolder + 'venues_info/venues_msoa_full.dat'
ward     = outfolder + 'venues_info/venues_ward_full.dat'
networks = outfolder + '/networks/' + city + '_COMBINED_networkmeasures.csv'


'''  RUN SUM NETWORKS STUFFS FOR              '''
'''  ADD NETWORK STUFF W DIFFERENT BACKBONES  '''
# Out:
# '  ADD NETWORK STUFF W DIFFERENT BACKBONES  '

# %%
df_lsoa     = pd.read_csv(lsoa,      sep = '\t', index_col=0) 
df_msoa     = pd.read_csv(msoa,      sep = '\t', index_col=0) 
df_ward     = pd.read_csv(ward,      sep = '\t', index_col=0) 
#networks     = pd.read_csv(networks,      sep = '\t', index_col=0)

# %%
df_ward
# Out:
#                              venue        lng   lat\ward      lng0       lat0  \
# 52f65251498e29de0a83a038 -0.199080  51.481145  E05000254 -0.210810  51.479264
# 4f2b21c8e4b0e0a3466d9c6b -0.127209  51.513956  E05000138 -0.130472  51.512652
# 4c6f9b6adf6b8cfaefb9b54d -0.200837  51.476131  E05000264 -0.211414  51.469308
# 4bdee6900ee3a5936e3c32b0 -0.138488  51.517954  E05000649 -0.158366  51.501861
# 547edc29498e8b8ae8d244f0 -0.132774  51.499467  E05000644 -0.151685  51.493703
# 51afb2f9498ef4ff33347838 -0.121238  51.491719  E05000427 -0.127167  51.484499
# 4ffeea2ae4b02b4ef98e8fb4 -0.080165  51.541250  E05009371 -0.086617  51.536650
# 543e68d5498ea549c9060773 -0.140774  51.551095  E05000139 -0.148252  51.545171
# 504f2d69e4b02fe73104615b -0.071129  51.507206  E05009330 -0.080190  51.501664
# 4c90ebde7f3b8cfac83c981e -0.109669  51.522383  E05000138 -0.130472  51.512652
# 4cc1e410bde8f04ddcdf9a4b -0.027678  51.511804  E05009327 -0.037065  51.510805
# ...
